# %% [markdown]
# # Embedding Model Selection

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import os
import sys
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import seaborn as sns
colours = sns.color_palette("Set2")
from sentence_transformers import SentenceTransformer, util
import warnings
warnings.filterwarnings("ignore")
from model_tester import test_embedding_models

project_root = os.path.abspath('..')
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from utils import get_table_from_supabase

#get keys from env
load_dotenv()
url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")

# %% [markdown]
# ## Recipient Objectives

# %% [markdown]
# Until this point, the database was limited to recipient names and activities. I have chosen to extend this to include recipient objectives to hopefully enrich the data and provide another context to test for the embedding model selection. I have updated the database builders, so that objectives can be imported from the start in future iterations, and also created `2_recipients_table_builder/recipient_objectives_importer.py` so that I do not have to re-build the entire database at this point in the project.

# %% [markdown]
# ----

# %% [markdown]
# # Retrieving Data from Supabase and Building Dataframes

# %% [markdown]
# I will connect to Supabase and retrieve the relevant records, in order to isolate the text data that I will use to embed and select the best model. For this purpose, I will use the 12 funder-recipient pairs that I have curated for my evaluation app.

# %%
#get embedding pairs and extract ids
embedding_pairs = get_table_from_supabase(url, key, "embedding_pairs")
funder_ids = embedding_pairs["funder_registered_num"].unique()
eval_recip_ids = embedding_pairs["recipient_id"].unique()

#add my ratings to compare later
ratings = {
    1: 0.70,
    2: 0.10,
    3: 0.50,
    4: 0.15,
    5: 0.5,
    6: 0.75,
    7: 0.5,
    8: 0.85,
    9: 0.20,
    10: 0.5,
    11: 0.70,
    12: 0.5
}
embedding_pairs["my_rating"] = embedding_pairs["id"].map(ratings)

# %%
#get the 12 funders and recipients
funders = get_table_from_supabase(url, key, "funders")
funders = funders[funders["registered_num"].isin(funder_ids)]

recipients = get_table_from_supabase(url, key, "recipients")
recipients = recipients[recipients["recipient_id"].isin(eval_recip_ids)]

#create dataframes
recipients_df = recipients.copy()
funders_df = funders.copy()

#add embedding columns to funder/recipient dfs
funders_df["embeddings"] = None
recipients_df["embeddings"] = None

#add funder and recipient names to pairs df
embedding_pairs = embedding_pairs.merge(
    funders_df[["registered_num", "name"]],
    left_on="funder_registered_num",
    right_on="registered_num",
    how="left"
)
embedding_pairs = embedding_pairs.rename(columns={"name": "funder_name"})
embedding_pairs = embedding_pairs.drop(columns=["registered_num"])
embedding_pairs = embedding_pairs.merge(
    recipients_df[["recipient_id", "recipient_name"]],
    on="recipient_id",
    how="left"
)

# %%
#check dfs
print(f"Recipients: {recipients_df.shape} | Funders: {funders_df.shape} | Evaluation Pairs: {embedding_pairs.shape}")
# Out:
# Recipients: (12, 6) | Funders: (12, 14) | Evaluation Pairs: (12, 6)

# %%
#create checkpoint - save dfs to pickle
recipients_df.to_pickle("recipients_df.pkl")
funders_df.to_pickle("funders_df.pkl")
embedding_pairs.to_pickle("embedding_pairs.pkl")

# %%
# recipients_df = pd.read_pickle("recipients_df.pkl")
# funders_df = pd.read_pickle("funders_df.pkl")
# embedding_pairs = pd.read_pickle("embedding_pairs.pkl")

# %% [markdown]
# ----

# %% [markdown]
# # Embedding Model Evaluation by Sections

# %% [markdown]
# I have chosen to test four models on my small evaluation dataset:
# - `all-MiniLM-L6-v2`
# - `snowflake-arctic-embed-s`
# - `all-roberta-large-v1`
# - `bge-large-en-v1.5`
#
# Snowflake's model is generally finetuned for retrieval but I have decided to include it as it has performed so highly against other benchmarks and compared to major competitors (Merrick et al, 2024). The other models are consistent with the analysis by Pavlyshenko and Stasiuk (2025), who found these architectures to be reliable on semantic similarity tasks.
#
# I will test each model on different sections from the funders and recipients dataframes, to determine which model produces embeddings that correlate best with my ratings, weighing up accuracy vs speed, and evaluating which section (or combination of sections) produces the best results.

# %%
#add model names
models = ["all-MiniLM-L6-v2", "Snowflake/snowflake-arctic-embed-s", "all-roberta-large-v1", "BAAI/bge-large-en-v1.5"]

# %% [markdown]
# ## Test 1 - Activities Only

# %%
#prepare text columns
recipients_df["recipients_text"] = recipients_df["recipient_activities"].fillna("").str.lower()
funders_df["funders_text"] = funders_df["activities"].fillna("").str.lower()

results_act = []

# %%
#test models
results_act_df, pairs_act = test_embedding_models(
    models_list=models,
    funders_df=funders_df,
    recipients_df=recipients_df,
    embedding_pairs=embedding_pairs
)
# Out:
# all-MiniLM-L6-v2: 3.2s
# Snowflake/snowflake-arctic-embed-s: 2.2s
# all-roberta-large-v1: 4.2s
# BAAI/bge-large-en-v1.5: 4.0s
#
# Total test time: 13.6s

# %%
results_act_df
# Out:
#                                 model  correlation
# 0                    all-MiniLM-L6-v2     0.606252
# 1  Snowflake/snowflake-arctic-embed-s     0.532136
# 2                all-roberta-large-v1     0.723535
# 3              BAAI/bge-large-en-v1.5     0.739029

# %%
#view pairs with scores from each model
pairs_act
# Out:
#     id funder_registered_num recipient_id  my_rating  \
# 0    1                283423       221219       0.70
# 1    2                313303      1154453       0.10
# 2    3               1011451       290462       0.50
# 3    4               1060133       267039       0.15
# 4    5               1189138      1187880       0.50
# 5    6               1041449      1147420       0.75
# 6    7                801518       238372       0.50
# 7    8               1199978       511702       0.85
# 8    9                296284      1204700       0.20
# 9   10                273422      1135842       0.50
# 10  11                294629      1137415       0.70
# 11  12               1016701      1152953       0.50
#
#                                          funder_name  \
# 0                                          GUR TRUST
# 1                                    MARC FITCH FUND
# 2                       CHRISTIAN DEVELOPMENT UGANDA
# 3                        HAMPSHIRE HOSPITALS CHARITY
# 4                          AFGHAN SPORTS TRUST (AST)
# 5                                           MIRACLES
# 6                    BARRY AND PEGGY HIGH FOUNDATION
# 7                         360 GRASS ROOTS FOUNDATION
# 8                                 INSPIRE FOUNDATION
# 9   BRITISH ASSOCIATION FOR CEMETERIES IN SOUTH ASIA
# 10                                 FENTON ARTS TRUST
# 11                                    SKERRITT TRUST
#
#                                        recipient_name  all-MiniLM-L6-v2_sim  \
# 0                             CARDIFF JEWISH HELPLINE              0.557142
# 1                          FRIENDS OF ANIMALS IN NEED              0.197431
# 2                            IBM UNITED KINGDOM TRUST              0.365567
# 3                                       SOLENT RESCUE              0.317997
# 4                                           ARTS4KENT              0.275089
# 5                                       BEYOND CANCER              0.483440
# 6                             SOMERSET WILDLIFE TRUST              0.134283
# 7                   HULL CHILDREN'S ADVENTURE SOCIETY              0.323242
# 8           ABERYSTWYTH TOWN FOOTBALL CLUB FOUNDATION              0.123979
# 9                                BRAIN TUMOUR BUDDIES              0.206509
# 10  SOUTH ASIAN DECORATIVE ARTS AND CRAFTS COLLECT...              0.464618
# 11                                  SHOUT FOR ORPHANS              0.209306
#
#     Snowflake/snowflake-arctic-embed-s_sim  all-roberta-large-v1_sim  \
# 0                                 0.793291                  0.602727
# 1                                 0.638527                  0.220884
# 2                                 0.789738                  0.518371
# 3                                 0.756214                  0.331801
# 4                                 0.657083                  0.371707
# 5                                 0.754553                  0.445960
# 6                                 0.728055                  0.282212
# 7                                 0.748191                  0.525078
# 8                                 0.572870                  0.135521
# 9                                 0.707212                  0.235069
# 10                                0.747314                  0.420953
# 11                                0.607622                  0.265997
#
#     BAAI/bge-large-en-v1.5_sim
# 0                     0.576528
# 1                     0.406419
# 2                     0.655457
# 3                     0.466332
# 4                     0.649507
# 5                     0.637562
# 6                     0.493692
# 7                     0.609121
# 8                     0.426864
# 9                     0.509568
# 10                    0.564178
# 11                    0.461674

# %% [markdown]
# ### Observations

# %% [markdown]
# None of the correlations for `activities` are exceptionally strong, but...

# %% [markdown]
# ## Test 2 - Objectives Only

# %%
#prepare text columns
recipients_df["recipients_text"] = recipients_df["recipient_objectives"].fillna("").str.lower()
funders_df["funders_text"] = funders_df["objectives"].fillna("").str.lower()

results_obj = []

# %%
#test models
results_obj_df, pairs_obj = test_embedding_models(
    models_list=models,
    funders_df=funders_df,
    recipients_df=recipients_df,
    embedding_pairs=embedding_pairs
)
# Out:
# all-MiniLM-L6-v2: 2.6s
# Snowflake/snowflake-arctic-embed-s: 2.6s
# all-roberta-large-v1: 5.9s
# BAAI/bge-large-en-v1.5: 5.0s
#
# Total test time: 16.1s

# %%
results_obj_df
# Out:
#                                 model  correlation
# 0                    all-MiniLM-L6-v2     0.327544
# 1  Snowflake/snowflake-arctic-embed-s     0.502695
# 2                all-roberta-large-v1     0.688371
# 3              BAAI/bge-large-en-v1.5     0.634833

# %%
pairs_obj
# Out:
#     id funder_registered_num recipient_id  my_rating  \
# 0    1                283423       221219       0.70
# 1    2                313303      1154453       0.10
# 2    3               1011451       290462       0.50
# 3    4               1060133       267039       0.15
# 4    5               1189138      1187880       0.50
# 5    6               1041449      1147420       0.75
# 6    7                801518       238372       0.50
# 7    8               1199978       511702       0.85
# 8    9                296284      1204700       0.20
# 9   10                273422      1135842       0.50
# 10  11                294629      1137415       0.70
# 11  12               1016701      1152953       0.50
#
#                                          funder_name  \
# 0                                          GUR TRUST
# 1                                    MARC FITCH FUND
# 2                       CHRISTIAN DEVELOPMENT UGANDA
# 3                        HAMPSHIRE HOSPITALS CHARITY
# 4                          AFGHAN SPORTS TRUST (AST)
# 5                                           MIRACLES
# 6                    BARRY AND PEGGY HIGH FOUNDATION
# 7                         360 GRASS ROOTS FOUNDATION
# 8                                 INSPIRE FOUNDATION
# 9   BRITISH ASSOCIATION FOR CEMETERIES IN SOUTH ASIA
# 10                                 FENTON ARTS TRUST
# 11                                    SKERRITT TRUST
#
#                                        recipient_name  all-MiniLM-L6-v2_sim  \
# 0                             CARDIFF JEWISH HELPLINE              0.437126
# 1                          FRIENDS OF ANIMALS IN NEED              0.432430
# 2                            IBM UNITED KINGDOM TRUST              0.403102
# 3                                       SOLENT RESCUE              0.440307
# 4                                           ARTS4KENT              0.409941
# 5                                       BEYOND CANCER              0.372780
# 6                             SOMERSET WILDLIFE TRUST              0.107357
# 7                   HULL CHILDREN'S ADVENTURE SOCIETY              0.546164
# 8           ABERYSTWYTH TOWN FOOTBALL CLUB FOUNDATION              0.184553
# 9                                BRAIN TUMOUR BUDDIES              0.297635
# 10  SOUTH ASIAN DECORATIVE ARTS AND CRAFTS COLLECT...              0.516720
# 11                                  SHOUT FOR ORPHANS              0.460756
#
#     Snowflake/snowflake-arctic-embed-s_sim  all-roberta-large-v1_sim  \
# 0                                 0.848325                  0.580698
# 1                                 0.766709                  0.415479
# 2                                 0.794509                  0.437849
# 3                                 0.788002                  0.346878
# 4                                 0.824745                  0.591121
# 5                                 0.744481                  0.450273
# 6                                 0.731397                  0.340071
# 7                                 0.833259                  0.640340
# 8                                 0.675054                  0.243412
# 9                                 0.753520                  0.357773
# 10                                0.839069                  0.537554
# 11                                0.818231                  0.363066
#
#     BAAI/bge-large-en-v1.5_sim
# 0                     0.528188
# 1                     0.542128
# 2                     0.624729
# 3                     0.524049
# 4                     0.688336
# 5                     0.617626
# 6                     0.502861
# 7                     0.730950
# 8                     0.507999
# 9                     0.576838
# 10                    0.720075
# 11                    0.616049

# %% [markdown]
# ### Observations

# %% [markdown]
# ## Test 3 - Activities and Objectives (API Only)

# %%
#prepare text columns
recipients_df["recipients_text"] = recipients_df["recipient_activities"].fillna("") + "" + recipients_df["recipient_objectives"].fillna("").str.lower()
funders_df["funders_text"] = funders_df["activities"].fillna("") + "" + funders_df["objectives"].fillna("").str.lower()

results_ao_api = []

# %%
#test models
results_ao_api, pairs_ao_api = test_embedding_models(
    models_list=models,
    funders_df=funders_df,
    recipients_df=recipients_df,
    embedding_pairs=embedding_pairs
)
# Out:
# all-MiniLM-L6-v2: 2.2s
# Snowflake/snowflake-arctic-embed-s: 2.5s
# all-roberta-large-v1: 5.2s
# BAAI/bge-large-en-v1.5: 5.6s
#
# Total test time: 15.5s

# %%
results_ao_api
# Out:
#                                 model  correlation
# 0                    all-MiniLM-L6-v2     0.746534
# 1  Snowflake/snowflake-arctic-embed-s     0.598159
# 2                all-roberta-large-v1     0.807066
# 3              BAAI/bge-large-en-v1.5     0.795902

# %%
pairs_ao_api
# Out:
#     id funder_registered_num recipient_id  my_rating  \
# 0    1                283423       221219       0.70
# 1    2                313303      1154453       0.10
# 2    3               1011451       290462       0.50
# 3    4               1060133       267039       0.15
# 4    5               1189138      1187880       0.50
# 5    6               1041449      1147420       0.75
# 6    7                801518       238372       0.50
# 7    8               1199978       511702       0.85
# 8    9                296284      1204700       0.20
# 9   10                273422      1135842       0.50
# 10  11                294629      1137415       0.70
# 11  12               1016701      1152953       0.50
#
#                                          funder_name  \
# 0                                          GUR TRUST
# 1                                    MARC FITCH FUND
# 2                       CHRISTIAN DEVELOPMENT UGANDA
# 3                        HAMPSHIRE HOSPITALS CHARITY
# 4                          AFGHAN SPORTS TRUST (AST)
# 5                                           MIRACLES
# 6                    BARRY AND PEGGY HIGH FOUNDATION
# 7                         360 GRASS ROOTS FOUNDATION
# 8                                 INSPIRE FOUNDATION
# 9   BRITISH ASSOCIATION FOR CEMETERIES IN SOUTH ASIA
# 10                                 FENTON ARTS TRUST
# 11                                    SKERRITT TRUST
#
#                                        recipient_name  all-MiniLM-L6-v2_sim  \
# 0                             CARDIFF JEWISH HELPLINE              0.516422
# 1                          FRIENDS OF ANIMALS IN NEED              0.210857
# 2                            IBM UNITED KINGDOM TRUST              0.420214
# 3                                       SOLENT RESCUE              0.353044
# 4                                           ARTS4KENT              0.301765
# 5                                       BEYOND CANCER              0.521312
# 6                             SOMERSET WILDLIFE TRUST              0.169243
# 7                   HULL CHILDREN'S ADVENTURE SOCIETY              0.559026
# 8           ABERYSTWYTH TOWN FOOTBALL CLUB FOUNDATION              0.176115
# 9                                BRAIN TUMOUR BUDDIES              0.227425
# 10  SOUTH ASIAN DECORATIVE ARTS AND CRAFTS COLLECT...              0.606978
# 11                                  SHOUT FOR ORPHANS              0.348700
#
#     Snowflake/snowflake-arctic-embed-s_sim  all-roberta-large-v1_sim  \
# 0                                 0.789165                  0.579361
# 1                                 0.661811                  0.142984
# 2                                 0.812708                  0.453675
# 3                                 0.761814                  0.320771
# 4                                 0.677543                  0.413856
# 5                                 0.742330                  0.570350
# 6                                 0.684901                  0.200548
# 7                                 0.838391                  0.513512
# 8                                 0.583986                  0.240978
# 9                                 0.734453                  0.362744
# 10                                0.804424                  0.474813
# 11                                0.620932                  0.274380
#
#     BAAI/bge-large-en-v1.5_sim
# 0                     0.630517
# 1                     0.504471
# 2                     0.680943
# 3                     0.523628
# 4                     0.654139
# 5                     0.666375
# 6                     0.514936
# 7                     0.734836
# 8                     0.520629
# 9                     0.562164
# 10                    0.720858
# 11                    0.525637

# %% [markdown]
# ## Test 4 - Activities and Objectives (Extracted and API)

# %%
#prepare text columns
recipients_df["recipients_text"] = recipients_df["recipient_activities"].fillna("") + "" + recipients_df["recipient_objectives"].fillna("").str.lower()
funders_df["funders_text"] = funders_df["activities"].fillna("") + "" + funders_df["objectives"].fillna("") + "" + funders_df["objectives_activities"].fillna("").str.lower()

results_ao_ext = []

# %%
#test models
results_ao_ext, pairs_ao_ext = test_embedding_models(
    models_list=models,
    funders_df=funders_df,
    recipients_df=recipients_df,
    embedding_pairs=embedding_pairs
)
# Out:
# all-MiniLM-L6-v2: 2.5s
# Snowflake/snowflake-arctic-embed-s: 2.9s
# all-roberta-large-v1: 6.1s
# BAAI/bge-large-en-v1.5: 6.3s
#
# Total test time: 17.8s

# %%
results_ao_ext
# Out:
#                                 model  correlation
# 0                    all-MiniLM-L6-v2     0.721848
# 1  Snowflake/snowflake-arctic-embed-s     0.769735
# 2                all-roberta-large-v1     0.891904
# 3              BAAI/bge-large-en-v1.5     0.825110

# %%
pairs_ao_ext
# Out:
#     id funder_registered_num recipient_id  my_rating  \
# 0    1                283423       221219       0.70
# 1    2                313303      1154453       0.10
# 2    3               1011451       290462       0.50
# 3    4               1060133       267039       0.15
# 4    5               1189138      1187880       0.50
# 5    6               1041449      1147420       0.75
# 6    7                801518       238372       0.50
# 7    8               1199978       511702       0.85
# 8    9                296284      1204700       0.20
# 9   10                273422      1135842       0.50
# 10  11                294629      1137415       0.70
# 11  12               1016701      1152953       0.50
#
#                                          funder_name  \
# 0                                          GUR TRUST
# 1                                    MARC FITCH FUND
# 2                       CHRISTIAN DEVELOPMENT UGANDA
# 3                        HAMPSHIRE HOSPITALS CHARITY
# 4                          AFGHAN SPORTS TRUST (AST)
# 5                                           MIRACLES
# 6                    BARRY AND PEGGY HIGH FOUNDATION
# 7                         360 GRASS ROOTS FOUNDATION
# 8                                 INSPIRE FOUNDATION
# 9   BRITISH ASSOCIATION FOR CEMETERIES IN SOUTH ASIA
# 10                                 FENTON ARTS TRUST
# 11                                    SKERRITT TRUST
#
#                                        recipient_name  all-MiniLM-L6-v2_sim  \
# 0                             CARDIFF JEWISH HELPLINE              0.499828
# 1                          FRIENDS OF ANIMALS IN NEED              0.170908
# 2                            IBM UNITED KINGDOM TRUST              0.366500
# 3                                       SOLENT RESCUE              0.353192
# 4                                           ARTS4KENT              0.301765
# 5                                       BEYOND CANCER              0.546377
# 6                             SOMERSET WILDLIFE TRUST              0.165137
# 7                   HULL CHILDREN'S ADVENTURE SOCIETY              0.559026
# 8           ABERYSTWYTH TOWN FOOTBALL CLUB FOUNDATION              0.176115
# 9                                BRAIN TUMOUR BUDDIES              0.134327
# 10  SOUTH ASIAN DECORATIVE ARTS AND CRAFTS COLLECT...              0.530567
# 11                                  SHOUT FOR ORPHANS              0.444634
#
#     Snowflake/snowflake-arctic-embed-s_sim  all-roberta-large-v1_sim  \
# 0                                 0.784770                  0.565029
# 1                                 0.640039                  0.155086
# 2                                 0.743815                  0.374264
# 3                                 0.727818                  0.287377
# 4                                 0.677543                  0.410907
# 5                                 0.752861                  0.569332
# 6                                 0.727363                  0.248324
# 7                                 0.838391                  0.548415
# 8                                 0.583986                  0.231459
# 9                                 0.666406                  0.333996
# 10                                0.778357                  0.493963
# 11                                0.672556                  0.467526
#
#     BAAI/bge-large-en-v1.5_sim
# 0                     0.646452
# 1                     0.455534
# 2                     0.576565
# 3                     0.545204
# 4                     0.654139
# 5                     0.660608
# 6                     0.507670
# 7                     0.734836
# 8                     0.520629
# 9                     0.515344
# 10                    0.734663
# 11                    0.586574

# %% [markdown]
# ## Visualisation of Best Results

# %%
#make scatterplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

for idx, (model_col, title) in enumerate([
    ("all-MiniLM-L6-v2_sim", "MiniLM"),
    ("Snowflake/snowflake-arctic-embed-s_sim", "Snowflake Arctic Embed"),
    ("all-roberta-large-v1_sim", "Roberta"),
    ("BAAI/bge-large-en-v1.5_sim", "BGE-M3")
]):
    axes[idx].scatter(pairs_ao_ext["my_rating"], pairs_ao_ext[model_col],
                        alpha=0.6, s=100, color=colours[idx])

    #show line of best fit
    z = np.polyfit(pairs_ao_ext["my_rating"], pairs_ao_ext[model_col], 1)
    p = np.poly1d(z)
    axes[idx].plot(pairs_ao_ext["my_rating"].sort_values(),
                    p(pairs_ao_ext["my_rating"].sort_values()),
                    "r-", alpha=0.5, linewidth=2)

    axes[idx].set_xlabel("My Rating")
    axes[idx].set_ylabel("Model Similarity Score")
    axes[idx].set_title(f"{title}\nCorrelation: {results_ao_ext.iloc[idx]['correlation']:.3f}")
    axes[idx].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
